# %%
# %run parenthesis.py
# Out:
# ...
# Task: Dyck-1
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,709
# Training:   0%|          | 1/300 [00:04<21:14,  4.26s/it]
# Epoch   0 | Loss: 0.3972 | Acc: 0.5429 | F1: 0.7037 | GradNorm: 0.0505 | Best_F1: 0.7037
# Training:   4%|▎         | 11/300 [00:39<17:22,  3.61s/it]
# Epoch  10 | Loss: 0.0207 | Acc: 0.9859 | F1: 0.9870 | GradNorm: 2.4794 | Best_F1: 0.9870
# Training:   7%|▋         | 21/300 [01:13<16:20,  3.51s/it]
# Epoch  20 | Loss: 0.0035 | Acc: 0.9993 | F1: 0.9994 | GradNorm: 0.0461 | Best_F1: 0.9994
# Training:  10%|█         | 31/300 [01:49<16:19,  3.64s/it]
# Epoch  30 | Loss: 0.0011 | Acc: 0.9998 | F1: 0.9998 | GradNorm: 0.0177 | Best_F1: 0.9998
# Training:  14%|█▎        | 41/300 [02:24<15:30,  3.59s/it]
# Epoch  40 | Loss: 0.0008 | Acc: 0.9998 | F1: 0.9999 | GradNorm: 0.0120 | Best_F1: 0.9999
# Training:  17%|█▋        | 51/300 [03:00<14:48,  3.57s/it]
# Epoch  50 | Loss: 0.0005 | Acc: 0.9998 | F1: 0.9999 | GradNorm: 0.0522 | Best_F1: 0.9999
# ...
