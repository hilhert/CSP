# %% [markdown]
# $x^\star_{j}=\sum_{t=1}^{T_j} ((\prod_{i=1}^{t}\alpha_{t-i}) x_i)$

# %%
# %run parenthesis.py
# Out:
# Using device: cuda
# Parameters: 4,043
# Training:   0%|          | 1/300 [00:04<21:39,  4.35s/it]
# Epoch   0 | Loss: 0.0440 | Acc: 0.9785 | F1: 0.0000 | GradNorm: 0.1066 | Best_F1: 0.0000
# Training:   4%|▎         | 11/300 [00:39<17:22,  3.61s/it]
# Epoch  10 | Loss: 0.0035 | Acc: 0.9785 | F1: 0.0000 | GradNorm: 0.0958 | Best_F1: 0.0000
# Training:   7%|▋         | 21/300 [01:14<16:20,  3.51s/it]
# Epoch  20 | Loss: 0.0012 | Acc: 0.9970 | F1: 0.9268 | GradNorm: 0.4510 | Best_F1: 0.9268
# Training:  10%|█         | 31/300 [01:49<15:55,  3.55s/it]
# Epoch  30 | Loss: 0.0004 | Acc: 0.9975 | F1: 0.9383 | GradNorm: 0.0532 | Best_F1: 0.9383
# Training:  14%|█▎        | 41/300 [02:23<14:31,  3.36s/it]
# Epoch  40 | Loss: 0.0002 | Acc: 0.9995 | F1: 0.9882 | GradNorm: 0.1360 | Best_F1: 0.9882
# Training:  17%|█▋        | 51/300 [02:53<12:53,  3.11s/it]
# Epoch  50 | Loss: 0.0001 | Acc: 1.0000 | F1: 1.0000 | GradNorm: 0.0369 | Best_F1: 1.0000
# ...
