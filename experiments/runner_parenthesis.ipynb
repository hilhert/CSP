# %%
# %run parenthesis.py
# Out:
# ...
# Task: Dyck-1
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,709
# Training:   0%|          | 1/300 [00:04<22:12,  4.46s/it]
# Epoch   0 | Loss: 0.3950 | Acc: 0.5529 | F1: 0.7121 | GradNorm: 0.0698 | Best_F1: 0.7121
# Training:   4%|▎         | 11/300 [00:42<18:43,  3.89s/it]
# Epoch  10 | Loss: 0.0218 | Acc: 0.9880 | F1: 0.9893 | GradNorm: 5.7754 | Best_F1: 0.9893
# Training:   7%|▋         | 21/300 [01:20<18:02,  3.88s/it]
# Epoch  20 | Loss: 0.0043 | Acc: 0.9989 | F1: 0.9990 | GradNorm: 0.0214 | Best_F1: 0.9990
# Training:  10%|█         | 31/300 [01:59<17:42,  3.95s/it]
# Epoch  30 | Loss: 0.0011 | Acc: 0.9994 | F1: 0.9995 | GradNorm: 0.5780 | Best_F1: 0.9995
# Training:  14%|█▎        | 41/300 [02:37<17:10,  3.98s/it]
# Epoch  40 | Loss: 0.0007 | Acc: 0.9999 | F1: 1.0000 | GradNorm: 0.0184 | Best_F1: 1.0000
# Training:  17%|█▋        | 51/300 [03:15<16:13,  3.91s/it]
# Epoch  50 | Loss: 0.0002 | Acc: 0.9999 | F1: 0.9999 | GradNorm: 0.2712 | Best_F1: 1.0000
# ...
