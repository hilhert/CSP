# %%
# %run parenthesis.py
# Out:
# ...
# Task: Dyck-1
# ...
# Model: Mamba
# ...
# Model: Transformer
# ...
# Model: ComplexRNN
# ...
# Model: VanillaRNN
# ...
# Model: CSP-Fast
# ...
# Using device: cuda
# Parameters: 4,606
# Training:   0%|          | 1/300 [00:02<10:57,  2.20s/it]
# Epoch   0 | Loss: 0.3248 | Acc: 0.9316 | F1: 0.9389 | GradNorm: 12.0918 | Best_F1: 0.9389
# Training:   4%|▎         | 11/300 [00:18<08:13,  1.71s/it]
# Epoch  10 | Loss: 0.0175 | Acc: 0.9968 | F1: 0.9970 | GradNorm: 11.4204 | Best_F1: 0.9970
# Training:   7%|▋         | 21/300 [00:35<07:47,  1.67s/it]
# Epoch  20 | Loss: 0.0043 | Acc: 0.9985 | F1: 0.9986 | GradNorm: 0.4557 | Best_F1: 0.9986
# Training:  10%|█         | 31/300 [00:51<07:30,  1.67s/it]
# Epoch  30 | Loss: 0.0012 | Acc: 0.9996 | F1: 0.9996 | GradNorm: 3.8141 | Best_F1: 0.9996
# Training:  14%|█▎        | 41/300 [01:07<07:17,  1.69s/it]
# Epoch  40 | Loss: 0.0005 | Acc: 0.9986 | F1: 0.9987 | GradNorm: 0.1807 | Best_F1: 0.9996
# Training:  17%|█▋        | 51/300 [01:23<06:59,  1.69s/it]
# ...
