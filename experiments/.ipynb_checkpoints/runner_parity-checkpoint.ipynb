# %%
# %run parity.py
# Out:
# ...
# Model: Mamba
# ...
# Model: Transformer
# ...
# Model: ComplexRNN
# ...
# Using device: cuda
# Parameters: 9,730
# Training:   0%|          | 1/300 [00:04<21:27,  4.31s/it]
# Epoch   0 | Loss: 0.6856 | Acc: 0.6325 | F1: 0.6598 | GradNorm: 0.6426 | Best_F1: 0.6598
# Training:   4%|▎         | 11/300 [00:39<17:23,  3.61s/it]
# Epoch  10 | Loss: 0.0009 | Acc: 1.0000 | F1: 1.0000 | GradNorm: 0.0086 | Best_F1: 1.0000
# Training:   7%|▋         | 21/300 [01:14<16:46,  3.61s/it]
# Epoch  20 | Loss: 0.0002 | Acc: 1.0000 | F1: 1.0000 | GradNorm: 0.0024 | Best_F1: 1.0000
# Training:  10%|█         | 31/300 [01:49<16:07,  3.60s/it]
# Epoch  30 | Loss: 0.0001 | Acc: 1.0000 | F1: 1.0000 | GradNorm: 0.0009 | Best_F1: 1.0000
# Training:  14%|█▎        | 41/300 [02:24<15:35,  3.61s/it]
# Epoch  40 | Loss: 0.0000 | Acc: 1.0000 | F1: 1.0000 | GradNorm: 0.0005 | Best_F1: 1.0000
# Training:  17%|█▋        | 51/300 [02:59<14:51,  3.58s/it]
# ...
