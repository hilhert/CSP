# %%
# %run parity.py
# Out:
# Using device: cuda
# Parameters: 4,043
# Training:   0%|          | 1/300 [00:03<15:17,  3.07s/it]
# Epoch   0 | Loss: 0.6947 | Acc: 0.5050 | F1: 0.6711 | GradNorm: 0.2653 | Best_F1: 0.6711
# Training:   4%|▎         | 11/300 [00:29<14:02,  2.91s/it]
# Epoch  10 | Loss: 0.6937 | Acc: 0.5190 | F1: 0.5270 | GradNorm: 0.1673 | Best_F1: 0.6711
# Training:   7%|▋         | 21/300 [01:03<16:22,  3.52s/it]
# Epoch  20 | Loss: 0.6936 | Acc: 0.5195 | F1: 0.5154 | GradNorm: 0.4994 | Best_F1: 0.6711
# Training:  10%|█         | 31/300 [01:38<15:57,  3.56s/it]
# Epoch  30 | Loss: 0.6939 | Acc: 0.5050 | F1: 0.6711 | GradNorm: 0.6159 | Best_F1: 0.6711
# Training:  14%|█▎        | 41/300 [02:13<15:17,  3.54s/it]
# Epoch  40 | Loss: 0.6939 | Acc: 0.5050 | F1: 0.6711 | GradNorm: 0.1394 | Best_F1: 0.6711
# Training:  17%|█▋        | 51/300 [02:47<14:32,  3.50s/it]
# Epoch  50 | Loss: 0.6946 | Acc: 0.5050 | F1: 0.6711 | GradNorm: 0.6932 | Best_F1: 0.6711
# ...
