# %%
# %run parity.py
# Out:
# ...
# Task: parity
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,693
# Training:   0%|          | 1/300 [00:03<17:35,  3.53s/it]
# Epoch   0 | Loss: 0.6927 | Acc: 0.5279 | F1: 0.5285 | GradNorm: 0.0414 | Best_F1: 0.5285
# Training:   4%|▎         | 11/300 [00:32<15:24,  3.20s/it]
# Epoch  10 | Loss: 0.5173 | Acc: 0.6774 | F1: 0.6650 | GradNorm: 0.6141 | Best_F1: 0.6650
# Training:   7%|▋         | 21/300 [01:10<18:06,  3.89s/it]
# Epoch  20 | Loss: 1.2158 | Acc: 0.7331 | F1: 0.7186 | GradNorm: 1.6988 | Best_F1: 0.7186
# Training:  10%|█         | 31/300 [01:48<17:32,  3.91s/it]
# Epoch  30 | Loss: 30.5633 | Acc: 0.7560 | F1: 0.7565 | GradNorm: 2.8075 | Best_F1: 0.7565
# Training:  14%|█▎        | 41/300 [02:27<17:19,  4.02s/it]
# Epoch  40 | Loss: 0.3495 | Acc: 0.7705 | F1: 0.7800 | GradNorm: 2.4641 | Best_F1: 0.7800
# Training:  17%|█▋        | 51/300 [03:05<16:34,  3.99s/it]
# Epoch  50 | Loss: 0.3357 | Acc: 0.7853 | F1: 0.7926 | GradNorm: 6.4220 | Best_F1: 0.7926
# ...
