# %%
# %run parity.py
# Out:
# ...
# Task: parity
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,693
# Training:   0%|          | 1/300 [00:03<16:38,  3.34s/it]
# Epoch   0 | Loss: 0.7000 | Acc: 0.5353 | F1: 0.5326 | GradNorm: 0.0436 | Best_F1: 0.5326
# Training:   4%|▎         | 11/300 [00:33<14:45,  3.06s/it]
# Epoch  10 | Loss: 217.7416 | Acc: 0.7610 | F1: 0.7677 | GradNorm: 7.2133 | Best_F1: 0.7677
# Training:   7%|▋         | 21/300 [01:03<15:03,  3.24s/it]
# Epoch  20 | Loss: 2.1308 | Acc: 0.8652 | F1: 0.8662 | GradNorm: 2.4472 | Best_F1: 0.8662
# Training:  10%|█         | 31/300 [01:39<16:03,  3.58s/it]
# Epoch  30 | Loss: 19128.3114 | Acc: 0.9075 | F1: 0.9068 | GradNorm: 5.2891 | Best_F1: 0.9068
# Training:  14%|█▎        | 41/300 [02:13<15:11,  3.52s/it]
# Epoch  40 | Loss: 8.2660 | Acc: 0.9257 | F1: 0.9255 | GradNorm: 1.5975 | Best_F1: 0.9255
# Training:  17%|█▋        | 51/300 [02:48<14:59,  3.61s/it]
# Epoch  50 | Loss: 1.4768 | Acc: 0.9375 | F1: 0.9370 | GradNorm: 1.7225 | Best_F1: 0.9370
# ...
