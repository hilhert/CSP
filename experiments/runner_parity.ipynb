# %%
# %run parity.py
# Out:
# ...
# Task: parity
# ...
# Model: Mamba
# ...
# Model: Transformer
# ...
# Model: ComplexRNN
# ...
# Model: VanillaRNN
# ...
# Model: CSP-Fast
# ...
# Using device: cuda
# Parameters: 4,590
# Training:   0%|          | 1/300 [00:02<11:10,  2.24s/it]
# Epoch   0 | Loss: 0.6929 | Acc: 0.5206 | F1: 0.4789 | GradNorm: 3.3542 | Best_F1: 0.4789
# Training:   4%|▎         | 11/300 [00:18<08:07,  1.69s/it]
# Epoch  10 | Loss: 0.6309 | Acc: 0.5960 | F1: 0.5655 | GradNorm: 11.4552 | Best_F1: 0.5655
# Training:   7%|▋         | 21/300 [00:34<07:46,  1.67s/it]
# Epoch  20 | Loss: 0.6154 | Acc: 0.6164 | F1: 0.5943 | GradNorm: 9.8717 | Best_F1: 0.5943
# Training:  10%|█         | 31/300 [00:50<07:30,  1.67s/it]
# Epoch  30 | Loss: 0.4636 | Acc: 0.8130 | F1: 0.8028 | GradNorm: 105.9330 | Best_F1: 0.8028
# Training:  14%|█▎        | 41/300 [01:07<07:13,  1.67s/it]
# Epoch  40 | Loss: 0.3642 | Acc: 0.8917 | F1: 0.8956 | GradNorm: 90.5364 | Best_F1: 0.8956
# Training:  17%|█▋        | 51/300 [01:23<06:58,  1.68s/it]
# ...
