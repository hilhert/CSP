# %%
# %run mod3.py
# Out:
# ...
# Task: mod3
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,742
# Training:   0%|          | 1/300 [00:03<15:23,  3.09s/it]
# Epoch   0 | Loss: 1.1034 | Acc: 0.4031 | F1: 0.3154 | GradNorm: 0.0958 | Best_F1: 0.3154
# Training:   4%|▎         | 11/300 [00:28<12:23,  2.57s/it]
# Epoch  10 | Loss: 1.1610 | Acc: 0.6394 | F1: 0.6376 | GradNorm: 2.2757 | Best_F1: 0.6376
# Training:   7%|▋         | 21/300 [00:53<12:07,  2.61s/it]
# Epoch  20 | Loss: 3.4123 | Acc: 0.7072 | F1: 0.7068 | GradNorm: 10.7301 | Best_F1: 0.7068
# Training:  10%|█         | 31/300 [01:21<13:33,  3.02s/it]
# Epoch  30 | Loss: 7.1483 | Acc: 0.8448 | F1: 0.8453 | GradNorm: 137.6786 | Best_F1: 0.8453
# Training:  14%|█▎        | 41/300 [01:51<13:13,  3.06s/it]
# Epoch  40 | Loss: 83.9911 | Acc: 0.9303 | F1: 0.9296 | GradNorm: 36.9570 | Best_F1: 0.9296
# Training:  17%|█▋        | 51/300 [02:25<14:42,  3.54s/it]
# Epoch  50 | Loss: 30.0911 | Acc: 0.9526 | F1: 0.9519 | GradNorm: 5.5328 | Best_F1: 0.9519
# ...
