# %%
# %run mod3.py
# Out:
# ...
# Task: mod3
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,742
# Training:   0%|          | 1/300 [00:04<20:13,  4.06s/it]
# Epoch   0 | Loss: 1.0988 | Acc: 0.3697 | F1: 0.2922 | GradNorm: 0.0727 | Best_F1: 0.2922
# Training:   4%|▎         | 11/300 [00:40<18:35,  3.86s/it]
# Epoch  10 | Loss: 2.1778 | Acc: 0.6167 | F1: 0.6144 | GradNorm: 0.6385 | Best_F1: 0.6144
# Training:   7%|▋         | 21/300 [01:18<17:56,  3.86s/it]
# Epoch  20 | Loss: 31.4362 | Acc: 0.6954 | F1: 0.6949 | GradNorm: 6.1416 | Best_F1: 0.6949
# Training:  10%|█         | 31/300 [01:57<17:57,  4.01s/it]
# Epoch  30 | Loss: 47.3749 | Acc: 0.7853 | F1: 0.7859 | GradNorm: 3.3478 | Best_F1: 0.7859
# Training:  14%|█▎        | 41/300 [02:35<17:10,  3.98s/it]
# Epoch  40 | Loss: 7.1434 | Acc: 0.8919 | F1: 0.8915 | GradNorm: 6.2593 | Best_F1: 0.8915
# Training:  17%|█▋        | 51/300 [03:14<16:31,  3.98s/it]
# Epoch  50 | Loss: 1.0480 | Acc: 0.9569 | F1: 0.9570 | GradNorm: 14.6683 | Best_F1: 0.9570
# ...
