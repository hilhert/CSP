# %%
# %run mod3.py
# Out:
# ...
# Task: mod3
# ...
# Model: Mamba
# ...
# Using device: cuda
# Parameters: 18,742
# [Checkpoint] recovering training state: /home/lxh/Documents/my_notebooks/CSP/experiments/mod3/Mamba/mod3_Mamba_32_3.pt
# [Checkpoint] successfully recovered to  Epoch 31 | last Loss: 0.0001 | F1: 1.0000
# Eval length   8 | Acc: 1.0000 | F1: 1.0000
# Eval length  10 | Acc: 1.0000 | F1: 1.0000
# Eval length  12 | Acc: 1.0000 | F1: 1.0000
# Eval length  14 | Acc: 1.0000 | F1: 1.0000
# Eval length  16 | Acc: 1.0000 | F1: 1.0000
# Eval length  18 | Acc: 0.9987 | F1: 0.9987
# Eval length  20 | Acc: 0.9910 | F1: 0.9910
# Eval length  22 | Acc: 0.9710 | F1: 0.9710
# Eval length  24 | Acc: 0.9429 | F1: 0.9429
# Eval length  26 | Acc: 0.9123 | F1: 0.9122
# Eval length  28 | Acc: 0.8802 | F1: 0.8800
# Eval length  30 | Acc: 0.8514 | F1: 0.8511
# Eval length  32 | Acc: 0.8222 | F1: 0.8217
# Eval length  34 | Acc: 0.7953 | F1: 0.7947
# Eval length  36 | Acc: 0.7696 | F1: 0.7692
# Eval length  38 | Acc: 0.7484 | F1: 0.7479
# ...
