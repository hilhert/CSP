# %%
# %run mod3.py
# Out:
# Using device: cuda
# Parameters: 4,043
# Training:   0%|          | 1/300 [00:03<18:21,  3.68s/it]
# Epoch   0 | Loss: 0.6500 | Acc: 0.6515 | F1: 0.7890 | GradNorm: 0.2663 | Best_F1: 0.7890
# Training:   4%|▎         | 11/300 [00:36<17:02,  3.54s/it]
# Epoch  10 | Loss: 0.6377 | Acc: 0.6515 | F1: 0.7890 | GradNorm: 0.5745 | Best_F1: 0.7890
# Training:   7%|▋         | 21/300 [01:11<16:36,  3.57s/it]
# Epoch  20 | Loss: 0.1172 | Acc: 0.9655 | F1: 0.9735 | GradNorm: 67.4245 | Best_F1: 0.9735
# Training:  10%|█         | 31/300 [01:47<16:10,  3.61s/it]
# Epoch  30 | Loss: 0.0035 | Acc: 0.9985 | F1: 0.9988 | GradNorm: 0.2428 | Best_F1: 0.9988
# Training:  14%|█▎        | 41/300 [02:23<15:37,  3.62s/it]
# Epoch  40 | Loss: 0.0214 | Acc: 0.9970 | F1: 0.9977 | GradNorm: 0.1359 | Best_F1: 0.9988
# Training:  17%|█▋        | 51/300 [02:55<12:42,  3.06s/it]
# Epoch  50 | Loss: 0.0003 | Acc: 0.9995 | F1: 0.9996 | GradNorm: 0.0014 | Best_F1: 0.9996
# ...
